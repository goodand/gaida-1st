# %% [markdown]
# # '03_data_load.ipunb'
#
# ```
# 데이터분석/
# ㄴ namsan.csv
# ㄴ 03_data_load.ipynb

# %% [markdown]
# # CSV Load

# %%
# python으로 파일 불러오기
with open('./namsan.csv',encoding='EUC-KR') as f:
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,

# %%
# pandas로 csv -> DataFrame으로 불러오기
import pandas as pd

df = pd.read_csv('./namsan.csv',encoding='EUC-KR')

# DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./namsan.csv',encoding='EUC-KR') 5,9번 이슈, 메모리를 아끼기 위해서 생기는 오류
# Out:
# /var/folders/1p/yb8d7hmx6wd564h57_td4k140000gn/T/ipykernel_5312/837785466.py:4: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./namsan.csv',encoding='EUC-KR')

# %%
# pandas로 csv -> DataFrame으로 불러오기
import pandas as pd

df = pd.read_csv('./namsan.csv',encoding='EUC-KR',low_memory=False) # 메모리 세이빙 모드 끔
df = pd.read_csv('./namsan.csv',encoding='EUC-KR',dtype={
    'ISBN': str,
    '세트 ISBN' : str,
    '주제분류번호' : str 
})

# %%
df
# Out:
#             번호                                                도서명  \
# 0            1                                 감정을 이해하는 그림책 큐레이션
# 1            2                                  어른의 관계에는 마침표가 없다
# 2            3                               아무리 놀려도 괜찮은 책(독서치료용)
# 3            4                                나는 빛나는 3학년이야(독서치료용)
# 4            5  나는 왜 아무것도 하기 싫을까 :나도 모르게 방전된 몸과 마음을 회복하는 뇌과학 처방전
# ...        ...                                                ...
# 455551  455552                                          음악이 있는 풍경
# 455552  455553                                                큰오빠
# 455553  455554                                              뉴 웨이브
# 455554  455555                                       (최인훈 장편소설)화두
# 455555  455556                                       독일 문학과 세계 문학
#
#                                            저자     출판사  발행년도           ISBN  \
# 0       그림책심리성장연구소,강혜진,김애이,김은경,박소영,장미혜,차연주 지음      사우  2025  9791194126027
# ...

# %%
df.describe()
# Out:
#                   번호       세트 ISBN           도서권수           대출건수  Unnamed: 13
# count  455556.000000  2.728100e+04  455556.000000  455556.000000          0.0
# mean   227778.500000  9.788180e+12       1.127306      11.883617          NaN
# std    131507.833953  9.870186e+10       0.455262      18.157195          NaN
# min         1.000000  8.984980e+10       1.000000       0.000000          NaN
# 25%    113889.750000  9.788954e+12       1.000000       2.000000          NaN
# 50%    227778.500000  9.788972e+12       1.000000       6.000000          NaN
# 75%    341667.250000  9.788990e+12       1.000000      15.000000          NaN
# max    455556.000000  9.791199e+12      40.000000    1909.000000          NaN

# %%
df.dtypes # object로 뜨는건 하위 기준으로 설명 할 수 없어서 int,str 조합의 경우 등등
df.head(5)

# csv가 글러먹어서?
# Out:
# 번호               int64
# 도서명             object
# 저자              object
# 출판사             object
# 발행년도            object
# ISBN            object
# 세트 ISBN         object
# 부가기호            object
# 권               object
# 주제분류번호          object
# 도서권수             int64
# 대출건수             int64
# 등록일자            object
# Unnamed: 13    float64
# dtype: object

# %%
# csv 등 다른 확장자로 저장 가능, 
# df.to_csv('./test.csv',encoding='EUC-KR',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.to_csv(',/test.csv',encoding='EUC-KR')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
# ...

# %% [markdown]
# # Web API Load

# %%
# Data Parsing (분석, 해석)

import json


json_data = '{"a":1,"b":2}'
# 스트링이니깐 인덱스 접근이 안 된다. dict로 해석이 되지 않았다! => 파싱되지 않음
# json_data['a'] # error

import json

json.loads(json_data)

dict_data = json.loads(json_data)

print(type(json_data), type(dict_data))
# Out:
# <class 'str'> <class 'dict'>

# %%
# Data Serializing (직렬화) [dict -> json]
dict_data = '{"a":1,"b":2}' # json은 "" 쌍 따옴표가 중요해

import json
json_data = json.dumps(dict_data)

# %%
import requests
res = requests.get(URL)
